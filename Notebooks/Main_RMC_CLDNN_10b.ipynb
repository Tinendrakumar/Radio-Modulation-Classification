# %% [markdown]
# Import needed libraries

# %%
from scipy.io import loadmat
from pandas import factorize
import pickle
import numpy as np
import random
from scipy import signal
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model

# %% [markdown]
# Mount to Google Drive (optional)

# %%
# Mounting your Google Drive
# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# root_dir = "/content/gdrive/My Drive/"

# %% [markdown]
# ## Functions to load datasets

# %%
# RadioML2016.10a/10b or MIGOU MOD
def load_dataset(dataset):
    """
    Load and preprocess the dataset for use in machine learning models.

    Args:
        dataset (dict): A dictionary with keys as tuples (modulation, SNR) and values as I/Q data arrays.

    Returns:
        tuple: A tuple containing:
            - snrs (list): Sorted list of unique SNR values.
            - X (numpy.ndarray): Stacked array of I/Q data shaped as [num_of_samples, 128, 2].
            - modulations (list): Sorted list of unique modulation types.
            - one_hot_encode (numpy.ndarray): One-hot encoded labels for modulations.
            - lbl_SNR (numpy.ndarray): SNR labels for each data sample.
    """
    # Extract unique SNRs and modulations
    snrs = sorted(set(key[1] for key in dataset.keys()))
    modulations = sorted(set(key[0] for key in dataset.keys()))

    # Initialize lists for data and labels
    X, lbl = [], []

    # Populate the lists with data entries and corresponding labels
    for mod in modulations:
        for snr in snrs:
            X.append(dataset[(mod, snr)])
            lbl.extend([(mod, snr)] * dataset[(mod, snr)].shape[0])

    # Convert list to a single numpy array and reshape
    X = np.vstack(X)
    lbl = np.array(lbl)

    # Transpose dimensions of X to match [num_of_samples, 128, 2]
    X = np.transpose(X, (0, 2, 1))

    # Generate one-hot labels for modulations
    mod_indices = {mod: idx for idx, mod in enumerate(modulations)}
    one_hot_encode = np.eye(len(modulations))[np.vectorize(mod_indices.get)(lbl[:, 0])]

    # Prepare SNR labels for each sample
    repeat_n = X.shape[0] / (len(modulations) * len(snrs))
    lbl_SNR = np.tile(np.repeat(snrs, repeat_n), len(modulations))

    return snrs, X, modulations, one_hot_encode, lbl_SNR

# %%
def load_RMLb_dataset(X, lbl):
    """
    Load and preprocess the RML2016.10b dataset.

    Args:
        X (numpy.ndarray): Array of I/Q data.
        lbl (numpy.ndarray): Labels containing modulations and SNR values.

    Returns:
        tuple: A tuple containing:
            - snrs (list): Sorted list of unique SNR values.
            - X (numpy.ndarray): Input I/Q data.
            - mods (numpy.ndarray): Array of unique modulation types.
            - one_hot_encode (numpy.ndarray): One-hot encoded labels for modulations.
            - lbl_SNR (numpy.ndarray): SNR labels for each data sample.
    """
    mods = np.unique(lbl[:,0])
    snrs = np.unique(lbl[:,1]).astype(int)
    snrs.sort()

    # Map modulations to integers for one-hot encoding
    mod_to_index = {mod: index for index, mod in enumerate(mods)}
    mod_indices = np.vectorize(mod_to_index.get)(lbl[:, 0])
    one_hot_encode = to_categorical(mod_indices, num_classes=len(mods))

    # Prepare SNR labels for each sample
    num_samples_per_mod_snr = X.shape[0] // (len(mods) * len(snrs))
    lbl_SNR = np.repeat(snrs, num_samples_per_mod_snr * len(mods))

    return snrs.tolist(), X, mods, one_hot_encode, lbl_SNR

# %% [markdown]
# ## Functions to handle the datasets

# %%
import numpy as np

def train_test_valid_split(X, one_hot, train_split=0.7, valid_split=0.15, test_split=0.15):
    """
    Efficiently splits the dataset into training, validation, and testing sets based on provided ratios.

    Args:
        X (numpy.ndarray): The input features.
        one_hot (numpy.ndarray): The one-hot encoded target labels.
        train_split (float, optional): Fraction of the data to be used for training. Defaults to 0.7.
        valid_split (float, optional): Fraction of the data to be used for validation. Defaults to 0.15.
        test_split (float, optional): Fraction of the data to be used for testing. Defaults to 0.15.

    Returns:
        tuple: Tuple containing indices and data for train, validation, and test sets.
    """
    assert np.isclose(train_split + valid_split + test_split, 1), "The splits must sum to 1!"

    # Set random seed for reproducibility
    np.random.seed(42)

    # Shuffle indices
    indices = np.random.permutation(X.shape[0])

    # Calculate split indices
    n_train = int(X.shape[0] * train_split)
    n_valid = int(X.shape[0] * valid_split)

    # Split the indices for train, validation, and test
    train_idx, valid_idx, test_idx = indices[:n_train], indices[n_train:n_train + n_valid], indices[n_train + n_valid:]

    # Split the data
    X_train, X_valid, X_test = X[train_idx], X[valid_idx], X[test_idx]
    Y_train, Y_valid, Y_test = one_hot[train_idx], one_hot[valid_idx], one_hot[test_idx]

    return train_idx, valid_idx, test_idx, X_train, X_valid, X_test, Y_train, Y_valid, Y_test

# %%
def normalize_data(X_train, X_valid, X_test):
    """
    Normalizes the training, validation, and test datasets using mean and standard deviation
    computed from the training data.

    Args:
        X_train, X_valid, X_test (numpy.ndarray): Data arrays to be normalized, assumed to be 3-dimensional.

    Returns:
        tuple: Normalized training, validation, and test data arrays.
    """
    mean = X_train.mean(axis=0)
    std = X_train.std(axis=0)

    X_train -= mean
    X_train /= std

    X_valid -= mean
    X_valid /= std
    X_test -= mean
    X_test /= std

    return X_train, X_valid, X_test

# %%
def return_indices_of_a(a, b):
    """
    Compare two lists a, b for same items and return indeces
    of the item in list a

    a:    List of items, its indeces will be returned
    b:    List of items to search for in list a

    """
    b_set = set(b)
    return [i for i, v in enumerate(a) if v in b_set]

# %% [markdown]
# ## Functions for plotting

# %%
def show_confusion_matrix(validations, predictions, matrix_snr, save=False):
    """
    Plot confusion matrix

    validations:    True Y labels
    predictions:    Predicted Y labels of your model
    matrix_snr:     SNR information for plot's titel
    """

    cm = confusion_matrix(validations, predictions)
    # Normalise
    cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(cmn, cmap='Blues', annot=True, fmt='.2f', xticklabels=mods, yticklabels=mods)
    sns.set(font_scale=1.3)
    if matrix_snr == None:
        plt.title("Confusion Matrix")
    else:
        plt.title("Confusion Matrix \n" + str(matrix_snr) + "dB")
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    if save == True:
        plt.savefig(base_dir + 'Own_dataset/' + str(matrix_snr) + '.png')
    plt.show(block=False)

# %%
def All_SNR_show_confusion_matrix(X_test, save=False):
    """
    Plot confusion matrix of all SNRs in one

    X_test:   X_test data
    """
    prediction = model.predict(X_test)

    Y_Pred = []; Y_Test = [];

    for i in range(len(prediction[:,0])):
        Y_Pred.append(np.argmax(prediction[i,:]))
        Y_Test.append(np.argmax(Y_test[i]))

    show_confusion_matrix(Y_Pred, Y_Test, None, save)

# %%
def SNR_show_confusion_matrix(in_snr, lbl_SNR, X_test, save=False):
    """
    Plot confusion matrices of chosen SNRs

    in_snr:   must be list of SNRs
    X_test:   X_test data
    """
    for snr in in_snr:
        matrix_snr = snr
        m_snr = matrix_snr;

        Y_Pred = []; Y_Test = []; Y_Pred_SNR = []; Y_Test_SNR = [];
        matrix_snr_index = [];

        prediction = model.predict(X_test)

        for i in range(len(prediction[:,0])):
            Y_Pred.append(np.argmax(prediction[i,:]))
            Y_Test.append(np.argmax(Y_test[i]))

        for i in range(len(lbl_SNR)):
            if int(lbl_SNR[i]) == m_snr:
                matrix_snr_index.append(i)

        indeces_of_Y_test = return_indices_of_a(test_idx, matrix_snr_index)

        for i in indeces_of_Y_test:
            Y_Pred_SNR.append(Y_Pred[i])
            Y_Test_SNR.append(Y_Test[i])
        show_confusion_matrix(Y_Pred_SNR, Y_Test_SNR, matrix_snr, save)

# %%
def plot_split_distribution(mods, Y_train, Y_valid, Y_test):

    x = np.arange(len(mods))  # the label locations
    width = 1  # the width of the bars

    fig, ax = plt.subplots()
    bar1 = ax.bar(x-width*0.3, np.count_nonzero(Y_train == 1, axis=0), width*0.3, label = "Train" )
    bar2 = ax.bar(x , np.count_nonzero(Y_valid == 1, axis=0), width*0.3, label = "Valid" )
    bar3 = ax.bar(x+width*0.3, np.count_nonzero(Y_test == 1, axis=0), width*0.3, label = "Test" )


    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Distribution')
    ax.set_title('Distribution overview of splitted dataset')
    ax.set_xticks(x)
    ax.set_xticklabels(mods)
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15),
            fancybox=True, shadow=True, ncol=5)


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 0),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    # autolabel(bar1)
    # autolabel(bar2)
    # autolabel(bar3)
    # fig.tight_layout()
    return plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras

# Assume these are defined somewhere in your notebook or script
global test_idx, lbl_SNR, X_test, Y_test, model

def SNR_accuracy(in_snr, name):
    """
    Computes and plots accuracies of chosen SNRs individually, assuming global variables for test indices,
    SNR labels, test features, test labels, and the model.

    Args:
        in_snr (list): List of SNRs to evaluate.
        name (str): Label name for the plot.

    Returns:
        numpy.ndarray: Array of accuracies for each SNR.
    """
    test_snr = lbl_SNR[test_idx]  # Extract test SNRs using indices
    acc = []

    for snr in in_snr:
        idx_acc_snr = np.where(test_snr == int(snr))[0]  # Get indices where SNR matches

        if idx_acc_snr.size > 0:
            acc_X_test = X_test[idx_acc_snr]
            acc_Y_test = Y_test[idx_acc_snr]
            print(f'\nSNR {snr} dB:')
            accuracy_snr = model.evaluate(acc_X_test, acc_Y_test, batch_size=32, verbose=2)
            acc.append(accuracy_snr)
        else:
            acc.append([0, 0])  # Handle case with no samples at this SNR

    acc = np.array(acc)
    # Plotting
    fig, ax = plt.subplots()
    ax.plot(in_snr, acc[:, 1] * 100, 'steelblue', marker='.', markersize=15, label=name, linestyle='-')
    ax.legend(loc='best', prop={'size': 15})
    ax.set_xticks(np.arange(min(in_snr), max(in_snr) + 1, 2))
    ax.set_yticks(np.arange(0, 101, 10))
    ax.set_yticks(np.arange(0, 101, 2), minor=True)
    ax.grid(True, which='both', linestyle='-', color='lightgray')
    ax.set_xlim(min(in_snr), max(in_snr))
    ax.set_ylim(0, 100)
    ax.set_title("Classification Accuracy by SNR", fontsize=20)
    ax.set_xlabel('SNR (dB)', fontsize=20)
    ax.set_ylabel('Accuracy (%)', fontsize=20)
    plt.show()

    return acc[:, 1]

# %% [markdown]
# ## Functions for visualization of layers

# %%
def layer_overview(model):

    """
    Offers overview of the model's layers and theirs outputs

    model: specify trained model you want to have overview of
    """

    # Names and outputs from layers
    layer_names = [layer.name for layer in model.layers]
    layer_outputs = [layer.output for layer in model.layers[:]]

    return layer_names, layer_outputs

def model_visualization(nth_layer, nth_test_idx, mods, model,
                        plot_sample = False, plot_activations = True,
                        plot_feature_maps = True):

    """
    The function provised overview of activation of specific layer and its
    feature maps.

    nth_layer: enter number which corresponds with the position of wanted layer
    nth_test_idx: enter number pointing at the test indexes from earlier
    mods: provide variable which holds listed modulations
    model: specify which trained model to load
    plot_sample = False: set to true to plot sample data
    plot_activations = True: plots activation of chosen layer
    plot_feature_maps = True: plots feature map of chosen layer
    """

    # Sample data for visualization
    test_sample = X_test[nth_test_idx,:,:] # shape [128,2]
    test_sample = test_sample[None] # change to needed [1,128,2]
    SNR = lbl_SNR[test_idx[nth_test_idx]]
    mod = one_hot[test_idx[nth_test_idx]]
    f, u = factorize(mods)
    mod = mod.dot(u)

    # Names and outputs from layers
    layer_names = [layer.name for layer in model.layers]
    layer_outputs = [layer.output for layer in model.layers[:]]

    ## Activations ##

    # define activation model
    activation_model = tf.keras.models.Model(model.input, layer_outputs)

    # get the activations of chosen test sample
    activations = activation_model.predict(test_sample)

    ## Feature-maps ##

    # define feature maps model
    feature_maps_model = tf.keras.models.Model(model.inputs, model.layers[4].output)

    # get the activated features
    feature_maps = feature_maps_model.predict(test_sample)


    # Plot sample
    if plot_sample == True:
        plt.plot(test_sample[0,:,:])
        plt.title(mod + '    ' + str(SNR) + 'dB')
        plt.show()

    # Plot activations
    if plot_activations == True:
        activation_layer = activations[nth_layer]
        activation_layer = np.transpose(activation_layer[:,:,:],(0,2,1)) # reshape
        fig, ax = plt.subplots(figsize=(20,10))
        ax.matshow(activation_layer[0,:,:],  cmap='viridis')
        # plt.matshow(activation_layer[0,:,:],  cmap='viridis')
        plt.title('Activation of layer ' + layer_names[nth_layer])
        ax.grid(False)
        ax.set_xlabel('Lenght of sequence')
        ax.set_ylabel('Filters')
        fig.show()
        plt.savefig(base_dir + 'activations.png')
        plt.savefig(base_dir + 'activations.svg')

    # Plot feature maps
    if plot_feature_maps == True:
        n_filters = int(feature_maps.shape[2]/2); ix = 1
        fig = plt.figure(figsize=(25,15))
        for _ in range(n_filters):
            for _ in range(2):
                # specify subplot and turn of axis
                ax =fig.add_subplot(n_filters,  5, ix)
                # ax = plt.subplot(n_filters,  5, ix, )
                ax.set_xticks([])
                ax.set_yticks([])
                # plot filter channel in grayscale
                ax.plot(feature_maps[0, :, ix-1])
                ix += 1
        # show the figure
        fig.show()
        plt.savefig(base_dir + 'feature_map.png')
        plt.savefig(base_dir + 'feature_map.svg')

# %% [markdown]
# # Access the datasets

# %% [markdown]
# ## RadioML Datasets
#
#
# *  O'shea, Timothy J., and Nathan West. "Radio machine learning dataset generation with gnu radio." Proceedings of the GNU Radio Conference. Vol. 1. No. 1. 2016.
#
# * The datasets are available at:  https://www.deepsig.ai/datasets
#
# *  All datasets provided by Deepsig Inc. are licensed under the Creative Commons Attribution -  [NonCommercial - ShareAlike 4.0 License (CC BY-NC-SA 4.0)](https://creativecommons.org/licenses/by-nc-sa/4.0/).
#
# Both datasets are left unchanged, however, the RadioML2016.10b version is not stored as the original data, but is already splitted into X and labels

# %%
dataset_pkl = open('/content/gdrive/MyDrive/Colab Notebooks/RMC/RML2016.10a_dict.pkl','rb')
RML_dataset_location = pickle.load(dataset_pkl, encoding='bytes')

# %%
RMLb_X_data_file = open('/content/gdrive/MyDrive/Colab Notebooks/RMC/RML2016.10b.pkl','rb')
RMLb_labels_file = open('/content/gdrive/MyDrive/Colab Notebooks/RMC/labels.pkl', 'rb')
RMLb_X = pickle.load(RMLb_X_data_file, encoding='bytes')
RMLb_lbl = pickle.load(RMLb_labels_file, encoding='ascii')

# %% [markdown]
# # Load the data

# %% [markdown]
# ## DeepSig Dataset

# %%
# 10a
# SNR, X, modulations, one_hot, lbl_SNR = load_dataset(RML_dataset_location)

# 10b
SNR, X, modulations, one_hot, lbl_SNR = load_RMLb_dataset(RMLb_X, RMLb_lbl)

# %%
mods = []
for i in range(len(modulations)):
    modu = modulations[i].decode('utf-8')
    mods.append(modu)

# %%
train_idx, valid_idx, test_idx, X_train, X_valid, X_test, Y_train, Y_valid, Y_test = train_test_valid_split(X, one_hot, train_split=0.7, valid_split=0.15, test_split=0.15)

# %%
plot_split_distribution(mods, Y_train, Y_valid, Y_test)

# %%
# X_train, X_valid, X_test = normalize_data(X_train, X_valid, X_test)

# %% [markdown]
# ## CLDNN

# %%
layer_in = keras.layers.Input(shape=(128,2))
layer = keras.layers.Conv1D(filters=64, kernel_size=8, activation='relu')(layer_in)
layer = keras.layers.MaxPool1D(pool_size=2)(layer)
layer = keras.layers.LSTM(64, return_sequences=True,)(layer)
layer = keras.layers.Dropout(0.4)(layer)
layer = keras.layers.LSTM(64, return_sequences=True,)(layer)
layer = keras.layers.Dropout(0.4)(layer)
layer = keras.layers.Flatten()(layer)
layer_out = keras.layers.Dense(len(mods), activation='softmax')(layer)

model_cldnn = keras.models.Model(layer_in, layer_out)

optimizer = keras.optimizers.Adam(learning_rate=0.0007)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "cldnn_model.h5", save_best_only=True, monitor="val_loss"),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.4, patience=5, min_lr=0.000007),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=8, verbose=1)]

model_cldnn.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
tf.keras.backend.clear_session()
history = model_cldnn.fit(X_train, Y_train, batch_size=128, epochs=110, verbose=2, validation_data= (X_valid, Y_valid), callbacks=callbacks)
# history = model_iq.fit(X_train, Y_train, batch_size=128, epochs=100, verbose=2, validation_split=0.15, callbacks=callbacks)
# Out:
# Epoch 1/110
# 6563/6563 - 88s - loss: 1.5828 - accuracy: 0.3594 - val_loss: 1.2373 - val_accuracy: 0.4763 - lr: 7.0000e-04 - 88s/epoch - 13ms/step
# Epoch 2/110
# 6563/6563 - 73s - loss: 1.2053 - accuracy: 0.4899 - val_loss: 1.1592 - val_accuracy: 0.5033 - lr: 7.0000e-04 - 73s/epoch - 11ms/step
# Epoch 3/110
# 6563/6563 - 72s - loss: 1.1182 - accuracy: 0.5277 - val_loss: 1.0663 - val_accuracy: 0.5510 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 4/110
# 6563/6563 - 72s - loss: 1.0695 - accuracy: 0.5500 - val_loss: 1.0392 - val_accuracy: 0.5635 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 5/110
# 6563/6563 - 72s - loss: 1.0459 - accuracy: 0.5593 - val_loss: 1.0203 - val_accuracy: 0.5723 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 6/110
# 6563/6563 - 76s - loss: 1.0317 - accuracy: 0.5670 - val_loss: 1.0026 - val_accuracy: 0.5826 - lr: 7.0000e-04 - 76s/epoch - 12ms/step
# Epoch 7/110
# 6563/6563 - 71s - loss: 1.0163 - accuracy: 0.5802 - val_loss: 0.9895 - val_accuracy: 0.5914 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 8/110
# 6563/6563 - 70s - loss: 0.9959 - accuracy: 0.5942 - val_loss: 0.9612 - val_accuracy: 0.6119 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 9/110
# 6563/6563 - 71s - loss: 0.9738 - accuracy: 0.6066 - val_loss: 0.9434 - val_accuracy: 0.6219 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 10/110
# 6563/6563 - 74s - loss: 0.9588 - accuracy: 0.6137 - val_loss: 0.9395 - val_accuracy: 0.6230 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 11/110
# 6563/6563 - 71s - loss: 0.9500 - accuracy: 0.6178 - val_loss: 0.9293 - val_accuracy: 0.6233 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 12/110
# 6563/6563 - 71s - loss: 0.9436 - accuracy: 0.6200 - val_loss: 0.9280 - val_accuracy: 0.6268 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 13/110
# 6563/6563 - 72s - loss: 0.9391 - accuracy: 0.6226 - val_loss: 0.9266 - val_accuracy: 0.6248 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 14/110
# 6563/6563 - 71s - loss: 0.9337 - accuracy: 0.6239 - val_loss: 0.9154 - val_accuracy: 0.6324 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 15/110
# 6563/6563 - 71s - loss: 0.9312 - accuracy: 0.6254 - val_loss: 0.9133 - val_accuracy: 0.6322 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 16/110
# 6563/6563 - 71s - loss: 0.9277 - accuracy: 0.6272 - val_loss: 0.9129 - val_accuracy: 0.6334 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 17/110
# 6563/6563 - 71s - loss: 0.9253 - accuracy: 0.6280 - val_loss: 0.9162 - val_accuracy: 0.6330 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 18/110
# 6563/6563 - 71s - loss: 0.9229 - accuracy: 0.6285 - val_loss: 0.9104 - val_accuracy: 0.6347 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 19/110
# 6563/6563 - 71s - loss: 0.9208 - accuracy: 0.6296 - val_loss: 0.9193 - val_accuracy: 0.6312 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 20/110
# 6563/6563 - 71s - loss: 0.9184 - accuracy: 0.6308 - val_loss: 0.9021 - val_accuracy: 0.6375 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 21/110
# 6563/6563 - 71s - loss: 0.9154 - accuracy: 0.6317 - val_loss: 0.9089 - val_accuracy: 0.6346 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 22/110
# 6563/6563 - 73s - loss: 0.9117 - accuracy: 0.6337 - val_loss: 0.9001 - val_accuracy: 0.6333 - lr: 7.0000e-04 - 73s/epoch - 11ms/step
# Epoch 23/110
# 6563/6563 - 71s - loss: 0.9099 - accuracy: 0.6338 - val_loss: 0.9037 - val_accuracy: 0.6370 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 24/110
# 6563/6563 - 70s - loss: 0.9085 - accuracy: 0.6345 - val_loss: 0.8980 - val_accuracy: 0.6392 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 25/110
# 6563/6563 - 70s - loss: 0.9064 - accuracy: 0.6352 - val_loss: 0.8974 - val_accuracy: 0.6354 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 26/110
# 6563/6563 - 70s - loss: 0.9052 - accuracy: 0.6360 - val_loss: 0.8955 - val_accuracy: 0.6409 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 27/110
# 6563/6563 - 70s - loss: 0.9037 - accuracy: 0.6365 - val_loss: 0.8960 - val_accuracy: 0.6406 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 28/110
# 6563/6563 - 74s - loss: 0.9021 - accuracy: 0.6371 - val_loss: 0.8920 - val_accuracy: 0.6372 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 29/110
# 6563/6563 - 71s - loss: 0.9008 - accuracy: 0.6372 - val_loss: 0.8921 - val_accuracy: 0.6351 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 30/110
# 6563/6563 - 71s - loss: 0.8998 - accuracy: 0.6376 - val_loss: 0.8919 - val_accuracy: 0.6404 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 31/110
# 6563/6563 - 70s - loss: 0.8983 - accuracy: 0.6387 - val_loss: 0.8895 - val_accuracy: 0.6424 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 32/110
# 6563/6563 - 70s - loss: 0.8972 - accuracy: 0.6392 - val_loss: 0.8913 - val_accuracy: 0.6396 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 33/110
# 6563/6563 - 70s - loss: 0.8960 - accuracy: 0.6399 - val_loss: 0.8935 - val_accuracy: 0.6413 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 34/110
# 6563/6563 - 70s - loss: 0.8951 - accuracy: 0.6398 - val_loss: 0.8855 - val_accuracy: 0.6437 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 35/110
# 6563/6563 - 70s - loss: 0.8940 - accuracy: 0.6402 - val_loss: 0.8936 - val_accuracy: 0.6410 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 36/110
# 6563/6563 - 71s - loss: 0.8930 - accuracy: 0.6410 - val_loss: 0.8890 - val_accuracy: 0.6424 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 37/110
# 6563/6563 - 74s - loss: 0.8923 - accuracy: 0.6409 - val_loss: 0.8841 - val_accuracy: 0.6447 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 38/110
# 6563/6563 - 71s - loss: 0.8913 - accuracy: 0.6415 - val_loss: 0.8858 - val_accuracy: 0.6438 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 39/110
# 6563/6563 - 70s - loss: 0.8903 - accuracy: 0.6422 - val_loss: 0.8882 - val_accuracy: 0.6432 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 40/110
# 6563/6563 - 71s - loss: 0.8894 - accuracy: 0.6420 - val_loss: 0.8828 - val_accuracy: 0.6447 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 41/110
# 6563/6563 - 74s - loss: 0.8891 - accuracy: 0.6423 - val_loss: 0.8849 - val_accuracy: 0.6438 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 42/110
# 6563/6563 - 71s - loss: 0.8880 - accuracy: 0.6429 - val_loss: 0.8847 - val_accuracy: 0.6439 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 43/110
# 6563/6563 - 72s - loss: 0.8876 - accuracy: 0.6428 - val_loss: 0.8821 - val_accuracy: 0.6456 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 44/110
# 6563/6563 - 71s - loss: 0.8866 - accuracy: 0.6433 - val_loss: 0.8863 - val_accuracy: 0.6448 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 45/110
# 6563/6563 - 71s - loss: 0.8859 - accuracy: 0.6437 - val_loss: 0.8836 - val_accuracy: 0.6444 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 46/110
# 6563/6563 - 71s - loss: 0.8844 - accuracy: 0.6441 - val_loss: 0.8860 - val_accuracy: 0.6433 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 47/110
# 6563/6563 - 70s - loss: 0.8839 - accuracy: 0.6441 - val_loss: 0.8803 - val_accuracy: 0.6458 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 48/110
# 6563/6563 - 71s - loss: 0.8833 - accuracy: 0.6443 - val_loss: 0.8796 - val_accuracy: 0.6450 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 49/110
# 6563/6563 - 71s - loss: 0.8822 - accuracy: 0.6447 - val_loss: 0.8804 - val_accuracy: 0.6429 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 50/110
# 6563/6563 - 71s - loss: 0.8820 - accuracy: 0.6452 - val_loss: 0.8773 - val_accuracy: 0.6468 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 51/110
# 6563/6563 - 70s - loss: 0.8809 - accuracy: 0.6451 - val_loss: 0.8791 - val_accuracy: 0.6452 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 52/110
# 6563/6563 - 70s - loss: 0.8805 - accuracy: 0.6450 - val_loss: 0.8794 - val_accuracy: 0.6460 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 53/110
# 6563/6563 - 70s - loss: 0.8805 - accuracy: 0.6452 - val_loss: 0.8782 - val_accuracy: 0.6457 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 54/110
# 6563/6563 - 70s - loss: 0.8795 - accuracy: 0.6458 - val_loss: 0.8761 - val_accuracy: 0.6441 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 55/110
# 6563/6563 - 70s - loss: 0.8792 - accuracy: 0.6456 - val_loss: 0.8778 - val_accuracy: 0.6468 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 56/110
# 6563/6563 - 70s - loss: 0.8786 - accuracy: 0.6462 - val_loss: 0.8773 - val_accuracy: 0.6457 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 57/110
# 6563/6563 - 71s - loss: 0.8783 - accuracy: 0.6464 - val_loss: 0.8779 - val_accuracy: 0.6478 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 58/110
# 6563/6563 - 70s - loss: 0.8773 - accuracy: 0.6464 - val_loss: 0.8775 - val_accuracy: 0.6441 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 59/110
# 6563/6563 - 70s - loss: 0.8771 - accuracy: 0.6467 - val_loss: 0.8755 - val_accuracy: 0.6463 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 60/110
# 6563/6563 - 70s - loss: 0.8764 - accuracy: 0.6472 - val_loss: 0.8848 - val_accuracy: 0.6428 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 61/110
# 6563/6563 - 70s - loss: 0.8762 - accuracy: 0.6471 - val_loss: 0.8753 - val_accuracy: 0.6470 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 62/110
# 6563/6563 - 71s - loss: 0.8756 - accuracy: 0.6472 - val_loss: 0.8767 - val_accuracy: 0.6467 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 63/110
# 6563/6563 - 70s - loss: 0.8752 - accuracy: 0.6474 - val_loss: 0.8752 - val_accuracy: 0.6470 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 64/110
# 6563/6563 - 74s - loss: 0.8746 - accuracy: 0.6473 - val_loss: 0.8763 - val_accuracy: 0.6476 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 65/110
# 6563/6563 - 71s - loss: 0.8741 - accuracy: 0.6478 - val_loss: 0.8748 - val_accuracy: 0.6475 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 66/110
# 6563/6563 - 71s - loss: 0.8738 - accuracy: 0.6477 - val_loss: 0.8739 - val_accuracy: 0.6488 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 67/110
# 6563/6563 - 71s - loss: 0.8732 - accuracy: 0.6485 - val_loss: 0.8758 - val_accuracy: 0.6477 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 68/110
# 6563/6563 - 70s - loss: 0.8734 - accuracy: 0.6482 - val_loss: 0.8732 - val_accuracy: 0.6481 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 69/110
# 6563/6563 - 71s - loss: 0.8727 - accuracy: 0.6483 - val_loss: 0.8765 - val_accuracy: 0.6472 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 70/110
# 6563/6563 - 71s - loss: 0.8723 - accuracy: 0.6486 - val_loss: 0.8736 - val_accuracy: 0.6479 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 71/110
# 6563/6563 - 71s - loss: 0.8718 - accuracy: 0.6488 - val_loss: 0.8732 - val_accuracy: 0.6476 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 72/110
# 6563/6563 - 72s - loss: 0.8713 - accuracy: 0.6492 - val_loss: 0.8730 - val_accuracy: 0.6480 - lr: 7.0000e-04 - 72s/epoch - 11ms/step
# Epoch 73/110
# 6563/6563 - 70s - loss: 0.8707 - accuracy: 0.6494 - val_loss: 0.8774 - val_accuracy: 0.6469 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 74/110
# 6563/6563 - 71s - loss: 0.8707 - accuracy: 0.6492 - val_loss: 0.8790 - val_accuracy: 0.6466 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 75/110
# 6563/6563 - 71s - loss: 0.8705 - accuracy: 0.6493 - val_loss: 0.8724 - val_accuracy: 0.6482 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 76/110
# 6563/6563 - 75s - loss: 0.8703 - accuracy: 0.6488 - val_loss: 0.8740 - val_accuracy: 0.6468 - lr: 7.0000e-04 - 75s/epoch - 11ms/step
# Epoch 77/110
# 6563/6563 - 71s - loss: 0.8705 - accuracy: 0.6491 - val_loss: 0.8752 - val_accuracy: 0.6478 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 78/110
# 6563/6563 - 70s - loss: 0.8703 - accuracy: 0.6499 - val_loss: 0.8777 - val_accuracy: 0.6476 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 79/110
# 6563/6563 - 71s - loss: 0.8695 - accuracy: 0.6500 - val_loss: 0.8730 - val_accuracy: 0.6480 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 80/110
# 6563/6563 - 71s - loss: 0.8693 - accuracy: 0.6500 - val_loss: 0.8717 - val_accuracy: 0.6477 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 81/110
# 6563/6563 - 70s - loss: 0.8688 - accuracy: 0.6505 - val_loss: 0.8747 - val_accuracy: 0.6480 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 82/110
# 6563/6563 - 71s - loss: 0.8685 - accuracy: 0.6502 - val_loss: 0.8733 - val_accuracy: 0.6476 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 83/110
# 6563/6563 - 71s - loss: 0.8681 - accuracy: 0.6497 - val_loss: 0.8730 - val_accuracy: 0.6484 - lr: 7.0000e-04 - 71s/epoch - 11ms/step
# Epoch 84/110
# 6563/6563 - 74s - loss: 0.8680 - accuracy: 0.6505 - val_loss: 0.8716 - val_accuracy: 0.6491 - lr: 7.0000e-04 - 74s/epoch - 11ms/step
# Epoch 85/110
# 6563/6563 - 70s - loss: 0.8678 - accuracy: 0.6506 - val_loss: 0.8737 - val_accuracy: 0.6474 - lr: 7.0000e-04 - 70s/epoch - 11ms/step
# Epoch 86/110
# 6563/6563 - 71s - loss: 0.8615 - accuracy: 0.6534 - val_loss: 0.8703 - val_accuracy: 0.6494 - lr: 2.8000e-04 - 71s/epoch - 11ms/step
# Epoch 87/110
# 6563/6563 - 70s - loss: 0.8605 - accuracy: 0.6537 - val_loss: 0.8710 - val_accuracy: 0.6485 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 88/110
# 6563/6563 - 71s - loss: 0.8603 - accuracy: 0.6539 - val_loss: 0.8691 - val_accuracy: 0.6489 - lr: 2.8000e-04 - 71s/epoch - 11ms/step
# Epoch 89/110
# 6563/6563 - 70s - loss: 0.8598 - accuracy: 0.6542 - val_loss: 0.8714 - val_accuracy: 0.6482 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 90/110
# 6563/6563 - 70s - loss: 0.8595 - accuracy: 0.6543 - val_loss: 0.8702 - val_accuracy: 0.6499 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 91/110
# 6563/6563 - 71s - loss: 0.8596 - accuracy: 0.6543 - val_loss: 0.8682 - val_accuracy: 0.6496 - lr: 2.8000e-04 - 71s/epoch - 11ms/step
# Epoch 92/110
# 6563/6563 - 71s - loss: 0.8593 - accuracy: 0.6543 - val_loss: 0.8699 - val_accuracy: 0.6488 - lr: 2.8000e-04 - 71s/epoch - 11ms/step
# Epoch 93/110
# 6563/6563 - 71s - loss: 0.8592 - accuracy: 0.6543 - val_loss: 0.8697 - val_accuracy: 0.6494 - lr: 2.8000e-04 - 71s/epoch - 11ms/step
# Epoch 94/110
# 6563/6563 - 75s - loss: 0.8588 - accuracy: 0.6545 - val_loss: 0.8676 - val_accuracy: 0.6492 - lr: 2.8000e-04 - 75s/epoch - 11ms/step
# Epoch 95/110
# 6563/6563 - 70s - loss: 0.8586 - accuracy: 0.6546 - val_loss: 0.8695 - val_accuracy: 0.6493 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 96/110
# 6563/6563 - 70s - loss: 0.8582 - accuracy: 0.6548 - val_loss: 0.8686 - val_accuracy: 0.6496 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 97/110
# 6563/6563 - 70s - loss: 0.8585 - accuracy: 0.6547 - val_loss: 0.8693 - val_accuracy: 0.6488 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 98/110
# 6563/6563 - 70s - loss: 0.8583 - accuracy: 0.6552 - val_loss: 0.8715 - val_accuracy: 0.6491 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 99/110
# 6563/6563 - 70s - loss: 0.8580 - accuracy: 0.6552 - val_loss: 0.8702 - val_accuracy: 0.6491 - lr: 2.8000e-04 - 70s/epoch - 11ms/step
# Epoch 100/110
# 6563/6563 - 75s - loss: 0.8556 - accuracy: 0.6563 - val_loss: 0.8683 - val_accuracy: 0.6494 - lr: 1.1200e-04 - 75s/epoch - 11ms/step
# Epoch 101/110
# 6563/6563 - 72s - loss: 0.8553 - accuracy: 0.6561 - val_loss: 0.8684 - val_accuracy: 0.6487 - lr: 1.1200e-04 - 72s/epoch - 11ms/step
# Epoch 102/110
# 6563/6563 - 70s - loss: 0.8546 - accuracy: 0.6566 - val_loss: 0.8696 - val_accuracy: 0.6496 - lr: 1.1200e-04 - 70s/epoch - 11ms/step
# Epoch 102: early stopping

# %%
model = keras.models.load_model("cldnn_model.h5")

test_loss, test_acc = model.evaluate(X_test, Y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 5625/5625 [==============================] - 26s 4ms/step - loss: 0.8699 - accuracy: 0.6503
# Test accuracy 0.650255560874939
# Test loss 0.8699445128440857

# %%
SNR_accuracy(SNR, 'CLDNN')
# Out:
# SNR -20dB:
# 285/285 - 2s - loss: 2.3697 - accuracy: 0.1101 - 2s/epoch - 7ms/step
#
# SNR -18dB:
# 282/282 - 1s - loss: 2.3384 - accuracy: 0.1155 - 1s/epoch - 5ms/step
#
# SNR -16dB:
# 283/283 - 1s - loss: 2.2801 - accuracy: 0.1314 - 1s/epoch - 4ms/step
#
# SNR -14dB:
# 282/282 - 1s - loss: 2.1685 - accuracy: 0.1578 - 1s/epoch - 5ms/step
#
# SNR -12dB:
# 283/283 - 1s - loss: 2.0170 - accuracy: 0.2064 - 1s/epoch - 4ms/step
#
# SNR -10dB:
# 281/281 - 1s - loss: 1.7393 - accuracy: 0.3162 - 1s/epoch - 4ms/step
#
# SNR -8dB:
# 284/284 - 1s - loss: 1.4316 - accuracy: 0.4276 - 1s/epoch - 5ms/step
#
# SNR -6dB:
# 282/282 - 1s - loss: 0.9953 - accuracy: 0.5925 - 1s/epoch - 5ms/step
#
# SNR -4dB:
# 283/283 - 1s - loss: 0.5669 - accuracy: 0.7513 - 1s/epoch - 4ms/step
#
# SNR -2dB:
# 283/283 - 1s - loss: 0.2793 - accuracy: 0.8758 - 1s/epoch - 4ms/step
#
# SNR 0dB:
# 280/280 - 1s - loss: 0.1576 - accuracy: 0.9170 - 1s/epoch - 4ms/step
#
# SNR 2dB:
# 281/281 - 1s - loss: 0.1264 - accuracy: 0.9340 - 1s/epoch - 4ms/step
#
# SNR 4dB:
# 281/281 - 1s - loss: 0.1256 - accuracy: 0.9313 - 1s/epoch - 4ms/step
#
# SNR 6dB:
# 285/285 - 1s - loss: 0.1115 - accuracy: 0.9367 - 1s/epoch - 5ms/step
#
# SNR 8dB:
# 284/284 - 1s - loss: 0.1199 - accuracy: 0.9335 - 1s/epoch - 5ms/step
#
# SNR 10dB:
# 282/282 - 1s - loss: 0.1024 - accuracy: 0.9398 - 1s/epoch - 4ms/step
#
# SNR 12dB:
# 280/280 - 1s - loss: 0.1039 - accuracy: 0.9405 - 1s/epoch - 4ms/step
#
# SNR 14dB:
# 282/282 - 1s - loss: 0.1081 - accuracy: 0.9355 - 1s/epoch - 4ms/step
#
# SNR 16dB:
# 276/276 - 1s - loss: 0.1050 - accuracy: 0.9340 - 1s/epoch - 4ms/step
#
# SNR 18dB:
# 276/276 - 1s - loss: 0.0984 - accuracy: 0.9382 - 1s/epoch - 4ms/step
# array([0.11012297, 0.11552547, 0.13139819, 0.15783639, 0.20638086,
#        0.31620026, 0.42762503, 0.59253913, 0.75127017, 0.87582928,
#        0.91696429, 0.93397909, 0.93131471, 0.93667692, 0.93353206,
#        0.93984461, 0.94046551, 0.93545878, 0.93399227, 0.93817234])

# %% [markdown]
# # Plot Confusion Matrix

# %%
All_SNR_show_confusion_matrix([X_test], save=False)

# %%
SNR_show_confusion_matrix(SNR, lbl_SNR[:], X_test, save=False)
